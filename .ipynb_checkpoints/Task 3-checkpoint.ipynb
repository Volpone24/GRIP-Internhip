# %% [markdown]
# # Intern Name - Rishab Goswami

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
store = pd.read_csv("SampleSuperstore.csv")

# %%
store.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
store.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
# Ship Mode       9994 non-null object
# Segment         9994 non-null object
# Country         9994 non-null object
# City            9994 non-null object
# State           9994 non-null object
# Postal Code     9994 non-null int64
# Region          9994 non-null object
# Category        9994 non-null object
# Sub-Category    9994 non-null object
# Sales           9994 non-null float64
# Quantity        9994 non-null int64
# Discount        9994 non-null float64
# Profit          9994 non-null float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
uniq_seg = store['Segment'].unique()
print("Segment Types: ",uniq_seg)
# Out:
# Segment Types:  ['Consumer' 'Corporate' 'Home Office']

# %%
uniq_city = store['City'].unique()
print("\nNo. of Cities: ",uniq_city)
# Out:
# No. of CIties:  ['Henderson' 'Los Angeles' 'Fort Lauderdale' 'Concord' 'Seattle'
#  'Fort Worth' 'Madison' 'West Jordan' 'San Francisco' 'Fremont'
#  'Philadelphia' 'Orem' 'Houston' 'Richardson' 'Naperville' 'Melbourne'
#  'Eagan' 'Westland' 'Dover' 'New Albany' 'New York City' 'Troy' 'Chicago'
#  'Gilbert' 'Springfield' 'Jackson' 'Memphis' 'Decatur' 'Durham' 'Columbia'
#  'Rochester' 'Minneapolis' 'Portland' 'Saint Paul' 'Aurora' 'Charlotte'
#  'Orland Park' 'Urbandale' 'Columbus' 'Bristol' 'Wilmington' 'Bloomington'
#  'Phoenix' 'Roseville' 'Independence' 'Pasadena' 'Newark' 'Franklin'
#  'Scottsdale' 'San Jose' 'Edmond' 'Carlsbad' 'San Antonio' 'Monroe'
#  'Fairfield' 'Grand Prairie' 'Redlands' 'Hamilton' 'Westfield' 'Akron'
#  'Denver' 'Dallas' 'Whittier' 'Saginaw' 'Medina' 'Dublin' 'Detroit'
#  'Tampa' 'Santa Clara' 'Lakeville' 'San Diego' 'Brentwood' 'Chapel Hill'
#  'Morristown' 'Cincinnati' 'Inglewood' 'Tamarac' 'Colorado Springs'
# ...

# %%
uniq_state = store['State'].unique()
print("\nNo. of State: ",uniq_state)
# Out:
# No. of State:  ['Kentucky' 'California' 'Florida' 'North Carolina' 'Washington' 'Texas'
#  'Wisconsin' 'Utah' 'Nebraska' 'Pennsylvania' 'Illinois' 'Minnesota'
#  'Michigan' 'Delaware' 'Indiana' 'New York' 'Arizona' 'Virginia'
#  'Tennessee' 'Alabama' 'South Carolina' 'Oregon' 'Colorado' 'Iowa' 'Ohio'
#  'Missouri' 'Oklahoma' 'New Mexico' 'Louisiana' 'Connecticut' 'New Jersey'
#  'Massachusetts' 'Georgia' 'Nevada' 'Rhode Island' 'Mississippi'
#  'Arkansas' 'Montana' 'New Hampshire' 'Maryland' 'District of Columbia'
#  'Kansas' 'Vermont' 'Maine' 'South Dakota' 'Idaho' 'North Dakota'
#  'Wyoming' 'West Virginia']

# %%
uniq_catg= store['Category'].unique()
print("\nNo. of Category: ",uniq_catg)
# Out:
# No. of Category:  ['Furniture' 'Office Supplies' 'Technology']

# %%
uniq_subcatg= store['Sub-Category'].unique()
print("\nNo. of Category: ",uniq_subcatg)
# Out:
# No. of Category:  ['Bookcases' 'Chairs' 'Labels' 'Tables' 'Storage' 'Furnishings' 'Art'
#  'Phones' 'Binders' 'Appliances' 'Paper' 'Accessories' 'Envelopes'
#  'Fasteners' 'Supplies' 'Machines' 'Copiers']

# %%
uniq_region= store['Region'].unique()
print("\nNo. of Category: ",uniq_region)
# Out:
# No. of Category:  ['South' 'West' 'Central' 'East']

# %% [markdown]
# # Correlation Between Data

# %%
plt.figure(figsize=(16,7))
correlation = sns.heatmap(store.corr(),annot=True)
plt.show()

# %%
plt.figure(figsize=(25,16))
sns.countplot(y="State", data=store)
plt.title('Distribution among States')
plt.show()

# %%
plt.figure(figsize=(16,100))
sns.countplot(y="City", data=store)
plt.title('Distribution among City')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.countplot(y="Region", data=store)
plt.title('Distribution among Z')
plt.show()

# %%
plt.figure(figsize=(7,7))
store['Category'].value_counts().plot.pie()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize=(7,7))
store['Sub-Category'].value_counts().plot.pie()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize=(7,7))
store['Segment'].value_counts().plot.pie()
plt.show()

# %%
tips = sns.load_dataset("tips")
sns.catplot(x="Category", y="Profit", data=store)

# %%
plt.figure(figsize=(16,6))
bar_plot1 = sns.barplot(x="Region",y="Profit", hue="Category", data=store)
plt.show()

# %%
plt.figure(figsize=(16,6))
bar_plot1 = sns.barplot(x="Region",y="Sales", hue="Category", data=store)
plt.show()

# %%
plt.figure(figsize=(40,16))
bar_plot1 = sns.barplot(x="Category",y="Profit", data=store)
plt.show()

# %%
plt.figure(figsize=(40,16))
bar_plot1 = sns.barplot(x="Sub-Category",y="Profit", data=store)
plt.show()

# %%
plt.figure(figsize=(40,16))
bar_plot1 = sns.barplot(x="Category",y="Sales", data=store)
plt.show()

# %%
plt.figure(figsize=(40,16))
bar_plot1 = sns.barplot(x="Sub-Category",y="Sales", data=store)
plt.show()

# %%
plt.figure(figsize=(40,16))
bar_plot1 = sns.barplot(x="Category",y="Quantity", data=store)
plt.show()

# %%
plt.figure(figsize=(40,16))
bar_plot1 = sns.barplot(x="Sub-Category",y="Quantity", data=store)
plt.show()

# %%
plt.figure(figsize=(40,16))
bar_plot1 = sns.barplot(x="Discount",y="Profit", data=store)
plt.show()

# %%
plt.figure(figsize=(40,16))
bar_plot1 = sns.barplot(x="Discount",y="Sales", data=store)
plt.show()

# %%
g = sns.FacetGrid(store, col="State",col_wrap=4, ylim=(0,13))
g.map(sns.barplot, "Category", "Profit")
